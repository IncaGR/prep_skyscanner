# %%
import pandas as pd
import numpy as np

from itertools import product

# %%
np.random.seed(42)

# %%
# fake_data = pd.DataFrame({})

countries = ['ESP','GBR','PRT','FRA']

dates = pd.date_range('2025-10-01','2026-03-31')

product_country_dates = list(product(countries,dates))

n = len(dates) * len(countries)

fake_data = pd.DataFrame(product_country_dates, columns=['country','dates'])


# countries_lst = np.random.choice(countries,n)
# dates_lst = np.random.choice(dates,n)

# searches = np.linspace(10000,50000,n) + np.random.randint(5000,10000,n)

# np.random.shuffle(searches)

# # bookings = np.where()
# fake_data = pd.DataFrame({'country':countries_lst,
#                           'date':dates_lst,
#                           'searches':searches})

# # print(n)

# fake_data['bookings'] = np.where((fake_data['date']>='2026-01-01') & (fake_data['country'].isin(['ESP', 'PRT'])), 
#                                  fake_data['searches']*0.05,
#                                  fake_data['searches']*0.03)


# fake_data['avg_price'] = 100 + fake_data['bookings']/100

print(fake_data)

print(dates)
# Out:
#     country      dates
# 0       ESP 2025-10-01
# 1       ESP 2025-10-02
# 2       ESP 2025-10-03
# 3       ESP 2025-10-04
# 4       ESP 2025-10-05
# ..      ...        ...
# 723     FRA 2026-03-27
# 724     FRA 2026-03-28
# 725     FRA 2026-03-29
# 726     FRA 2026-03-30
# 727     FRA 2026-03-31
#
# [728 rows x 2 columns]
# DatetimeIndex(['2025-10-01', '2025-10-02', '2025-10-03', '2025-10-04',
#                '2025-10-05', '2025-10-06', '2025-10-07', '2025-10-08',
#                '2025-10-09', '2025-10-10',
#                ...
#                '2026-03-22', '2026-03-23', '2026-03-24', '2026-03-25',
#                '2026-03-26', '2026-03-27', '2026-03-28', '2026-03-29',
#                '2026-03-30', '2026-03-31'],
#               dtype='datetime64[ns]', length=182, freq='D')
